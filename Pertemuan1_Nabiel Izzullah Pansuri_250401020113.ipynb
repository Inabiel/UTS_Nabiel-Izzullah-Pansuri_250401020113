# %% [markdown]
# # Hands On Sesi 1
#
# Nama : Nabiel Izzullah Pansuri
# NIM: 250401020113
# Kelas: IF403

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
nama = "Nabiel Izzullah Pansuri"
angkatan  = 2024
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Nabiel Izzullah Pansuri angkatan 2024!

# %%
tools = ["Python", "Colab", "Jupyter", "GitHub"]
for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Nabiel Izzullah Pansuri", "Informatika", 2024))
# Out:
# Nabiel Izzullah Pansuri | Informatika | 2024

# %% [markdown]
# # Kesimpulan
# Pada pertemuan sesi ini, saya belajar tentang instalasi python, dan syntax-syntax dasar python, beserta penggunaan fungsi (def())
